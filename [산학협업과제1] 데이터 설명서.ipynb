# %% [markdown]
# ## ★ 산학협엽과제 데이터 설명서
# * 데이터 소유권 현대자동차

# %% [markdown]
# - 변수명 및 데이터 정의
#     총 30개 File 전송
#     Out_1.csv ~ Out_30.csv

# %% [markdown]
# | 변수명        | 설명           |
# | ------------- |:-------------:|
# |	Time	|	시간	|
# |	FLSD	|	스프링 변위	|
# |	FLSARF	|	쇽업소버 로드 힘(Fz)	|
# |	FLSBLF	|	스탭바 링크 힘(Fa)	|
# |	FLFX	|	Fx	|
# |	FLFY	|	Fy	|
# |	FLFZ	|	Fz	|
# |	FLMX	|	Mx	|
# |	FLMY	|	My	|
# |	FLMZ	|	Mz	|
# |	FLLCABFX	|	로어암 힘(Fx)	|
# |	FLLCABFY	|	로어암 힘(Fy)	|
# |	FLTBF	|	FL볼조인트	|
# |	FRSD	|	스프링 변위	|
# |	FRSARF	|	쇽업소버 로드 힘(Fz)	|
# |	FRSBLF	|	스탭바 링크 힘(Fa)	|
# |	FRFX	|	Fx	|
# |	FRFY	|	Fy	|
# |	FRFZ	|	Fz	|
# |	FRMX	|	Mx	|
# |	FRMY	|	My	|
# |	FRMZ	|	Mz	|
# |	FRLCABFX	|	로어암 힘(Fx)	|
# |	FRLCABFY	|	로어암 힘(Fy)	|
# |	FRTBF	|	FL볼조인트	|
# |	RLSD	|	스프링 변위	|
# |	RLSARF	|	쇽업소버 로드 힘(Fz)	|
# |	RLSBLF	|	스탭바 링크 힘(Fa)	|
# |	RLFX	|	Fx	|
# |	RLFY	|	Fy	|
# |	RLFZ	|	Fz	|
# |	RLMX	|	Mx	|
# |	RLMY	|	My	|
# |	RLMZ	|	Mz	|
# |	RLUCAF	|	어퍼암 힘(Fa)	|
# |	RLAAF	|	어시스트암 힘(Fa)	|
# |	RLTAF	|	트레일링암 힘(Fx)	|
# |	RRSD	|	스프링 변위	|
# |	RRSARF	|	쇽업소버 로드 힘(Fz)	|
# |	RRSBLF	|	스탭바 링크 힘(Fa)	|
# |	RRFX	|	Fx	|
# |	RRFY	|	Fy	|
# |	RRFZ	|	Fz	|
# |	RRMX	|	Mx	|
# |	RRMY	|	My	|
# |	RRMZ	|	Mz	|
# |	RRUCAF	|	어퍼암 힘(Fa)	|
# |	RRAAF	|	어시스트암 힘(Fa)	|
# |	RRTAF	|	트레일링암 힘(Fx)	|
# |	ACCX	|	가속도 X	|
# |	ACCY	|	가속도 Y	|
# |	ACCZ	|	가속도 Z	|
# |	Latitude	|	위도	|
# |	Longitude	|	경도	|
# |	Speedkph	|	차속	|
# |	Pitching	|	Pitch	|
# |	Rolling	|	Roll	|
# |	VS	|	차속	|
# |	BRAKE_ACT	|	브레이크 작동	|
# |	SAS_Angle	|	스티어링 각도	|
# |	SAS_Speed	|	스티어링 속도	|
# |	PV_AV_CAN	|	악셀 궤도	|
# |	WHL_SPD_FL	|	휠속	|
# |	WHL_SPD_FR	|	휠속	|
# |	WHL_SPD_RL	|	휠속	|
# |	WHL_SPD_RR	|	휠속	|

# %%
# Sample Data Loading
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('F:/001. AI Data(19)/20빅데이터분석양성과정/분석과제1-하중예측/Out_1.csv')

# %%
plt.figure (figsize=(30,15))

# %%
df.describe()
# Out:
#                  Seq           Time           FLSD         FLSARF  \
# count  222227.000000  222227.000000  222227.000000  222227.000000
# mean   111114.000000    1111.130000     371.793646      -3.770108
# std     64151.553473     641.515535       4.958475      24.398752
# min         1.000000       0.000000     321.186600    -197.602800
# 25%     55557.500000     555.565000     369.848100     -17.567960
# 50%    111114.000000    1111.130000     371.869400      -5.961992
# 75%    166670.500000    1666.695000     374.284900       5.603209
# max    222227.000000    2222.260000     418.279400     286.910200
#
#               FLSBLF           FLFX           FLFY           FLFZ  \
# count  222227.000000  222227.000000  222227.000000  222227.000000
# mean       -6.683729     296.299378     305.762739    4799.507556
# std         6.915599     596.500301     322.987896     403.786876
# min       -67.775100   -3446.655000   -3110.721000     629.819800
# 25%       -10.081820       1.866588     191.102300    4600.333000
# 50%        -6.634797     287.118600     344.283100    4812.114000
# 75%        -2.733223     588.908500     470.750600    4984.606000
# max        53.581250    3765.916000    2226.787000    9627.661000
#
#                 FLMX           FLMY  ...        Rolling             VS  \
# count  222227.000000  222227.000000  ...  222227.000000  222227.000000
# mean     -515.616255     -52.009943  ...      -0.917765      35.240638
# std       129.937164     176.392304  ...       2.618377      19.180452
# min     -1521.990000   -1104.782000  ...     -10.189810       0.000000
# 25%      -573.432800    -132.219500  ...      -2.378538      23.000000
# 50%      -506.623700     -48.949460  ...      -0.796508      37.000000
# 75%      -444.049450      30.552455  ...       0.571289      48.000000
# max       286.735000     884.229500  ...       8.750604      85.000000
#
#            BRAKE_ACT      SAS_Angle      SAS_Speed      PV_AV_CAN  \
# count  222227.000000  222227.000000  222227.000000  222227.000000
# mean        1.178205    2924.882859       6.280258       6.053292
# std         0.381382    3222.073731      15.057131       7.585124
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       2.500000       0.000000       0.000000
# 50%         1.000000      24.253380       0.000000       1.953000
# 75%         1.000000    6545.100000       7.037011      11.327400
# max         2.000000    6553.500000     246.736900      34.763400
#
#           WHL_SPD_FL     WHL_SPD_FR     WHL_SPD_RL     WHL_SPD_RR
# count  222227.000000  222227.000000  222227.000000  222227.000000
# mean       36.348500      36.361925      36.171617      36.175124
# std        19.603939      19.632849      19.525526      19.550007
# min         0.000000       0.000000       0.000000       0.000000
# 25%        23.621660      23.588880      23.459925      23.437500
# 50%        37.922490      37.969230      37.726260      37.805110
# 75%        48.942875      49.005830      48.742490      48.766265
# max        86.779560      86.811470      86.401240      86.929060
#
# [8 rows x 67 columns]

# %%
df[['FLFX','FLSD','VS','SAS_Angle']].plot(figsize=(20,30), subplots=True, label=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000206F4DAC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000020700C630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000207037A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000207067EF0>],
#       dtype=object)
